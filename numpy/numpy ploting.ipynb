# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x= np.linspace(10,40,80)                 #an array of 100 elements, equally spaced from -40 to 40
y= np.sin(x)                               # an array with sin values of above...

# %%
# %matplotlib inline                      #use this, so that your pyplot gets visible. 
                                        #This is like getche() of C, which was used to display input enetered by user.
# Out:
# UsageError: unrecognized arguments: #use this, so that your pyplot gets visible.

# %%
plt.plot(x,y)                         #Plotting a Sine Graph
